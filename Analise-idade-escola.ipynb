# %%
import pandas as pd
import matplotlib.pyplot as plt
low_memory = False

# %%
dataf_15 = pd.read_csv(r'MICRODADOS_ENEM_2015.csv', delimiter= ',' , encoding='iso-8859-1', usecols=['TP_ESCOLA','NU_IDADE'])
dataf_16 = pd.read_csv(r'MICRODADOS_ENEM_2016.csv', delimiter= ';' , encoding='iso-8859-1', usecols=['TP_ESCOLA','NU_IDADE'])
dataf_17 = pd.read_csv(r'MICRODADOS_ENEM_2017.csv', delimiter= ';' , encoding='iso-8859-1', usecols=['TP_ESCOLA','NU_IDADE'])
dataf_18 = pd.read_csv(r'MICRODADOS_ENEM_2018.csv', delimiter= ';' , encoding='iso-8859-1', usecols=['TP_ESCOLA','NU_IDADE'])

# %%
data_15 = pd.crosstab(dataf_15.NU_IDADE,dataf_15.TP_ESCOLA)
data_16 = pd.crosstab(dataf_16.NU_IDADE,dataf_16.TP_ESCOLA)
data_17 = pd.crosstab(dataf_17.NU_IDADE, dataf_17.TP_ESCOLA)
data_18 = pd.crosstab(dataf_18.NU_IDADE, dataf_18.TP_ESCOLA)

# %%
data_15.plot()
data_16.plot()
data_17.plot()
data_18.plot()
